# %%
# Import necessary libraries
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load both JSON files
results_file = "evaluation_section.json"
results_total_file = "evaluation_total.json"

with open(results_file, 'r') as f:
    data = json.load(f)

with open(results_total_file, 'r') as f:
    data_total = json.load(f)

# %%
# Convert JSON into a structured format
models_data = []
for dataset in [data, data_total]:  # Loop through both files
    for model in dataset['models']:
        model_name = model['model_name']
        for checkpoint in model['checkpoint']:
            checkpoint_name = checkpoint['model_checkpoint']
            for dataset in checkpoint['val_datasets']:
                dataset_name = dataset['dataset_name']
                metrics = dataset['metrics']
                num_samples = dataset['num_samples']
                models_data.append({
                    "model_name": model_name,
                    "checkpoint": checkpoint_name,
                    "dataset": dataset_name,
                    **metrics,
                    "num_samples": num_samples
                })

# %%
# Create a DataFrame for easier handling
df = pd.DataFrame(models_data)
df
# Out:
#                    model_name          checkpoint  \
# 0   efficientnet_b1_greyscale  model_epoch_19.pth
# 1   efficientnet_b1_greyscale  model_epoch_19.pth
# 2   efficientnet_b1_greyscale  model_epoch_19.pth
# 3   efficientnet_b1_greyscale  model_epoch_19.pth
# 4   efficientnet_b1_greyscale  model_epoch_19.pth
# ..                        ...                 ...
# 75         resnet34_greyscale  model_epoch_21.pth
# 76              resnet18_full  model_epoch_10.pth
# 77       efficientnet_b0_full  model_epoch_25.pth
# 78              s2d_greyscale   model_epoch_7.pth
# 79                   s2d_full  model_epoch_27.pth
#
#                         dataset  accuracy  precision    recall  f1_score  \
# 0        E01_Global_val_lab.txt  0.985508   0.984344  0.986695  0.985518
# 1   E04_Local_Match_val_lab.txt  0.973992   0.983976  0.963653  0.973708
# 2           E05_DST_val_lab.txt  0.987173   0.984396  0.990028  0.987204
# 3        E06_Twente_val_lab.txt  0.985219   0.984335  0.986117  0.985225
# 4       E07_Lincoln_val_lab.txt  0.983435   0.984279  0.982548  0.983413
# ..                          ...       ...        ...       ...       ...
# 75                        total  0.978233   0.995110  0.979803  0.987397
# 76                        total  0.968356   0.995794  0.967726  0.981560
# 77                        total  0.975679   0.997463  0.974532  0.985864
# 78                        total  0.941389   0.986148  0.945940  0.965626
# 79                        total  0.942210   0.990995  0.942158  0.965960
#
#        macer     bpcer  macer_at_bpcer  num_samples
# 0   0.013305  0.015678        0.018685        76247
# 1   0.036347  0.015678        0.047290        76247
# 2   0.009972  0.015678        0.013489        76247
# 3   0.013883  0.015678        0.019525        76247
# 4   0.017452  0.015678        0.023225        76247
# ..       ...       ...             ...          ...
# 75  0.020197  0.032299        0.043882       297147
# 76  0.032274  0.027422        0.067892       297147
# 77  0.025468  0.016629        0.034981       297147
# 78  0.054060  0.089140        0.232192       297147
# 79  0.057842  0.057438        0.187165       297147
#
# [80 rows x 11 columns]

# %%
def single_metric():
    """
    Generates a bar chart of MACER@BPCER by dataset for each model.
    Excludes checkpoints from the x-axis labels.
    """
    # Remove checkpoint info from model names for plotting
    df['model_plot_label'] = df['model_name']

    # Filter only relevant metric
    numeric_cols = ['macer_at_bpcer']
    grouped = df.groupby(["model_plot_label", "dataset"])[numeric_cols].mean()

    # Unstack for plotting
    macer_data = grouped['macer_at_bpcer'].unstack()

    # Plot
    macer_data.plot(kind='bar', figsize=(14, 6), alpha=0.8, edgecolor='black')
    plt.title("MACER@BPCER by Dataset for Each Model", fontsize=16)
    plt.ylabel("MACER@BPCER", fontsize=14)
    plt.xlabel("Model", fontsize=14)
    plt.xticks(rotation=15, fontsize=12, ha='right')
    plt.legend(title="Dataset", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
single_metric()

# %%
def NIST_metrics():
    """
    Generates a bar chart of MACER, BPCER, and MACER@BPCER for each model, 
    focusing only on the 'total' dataset.
    Excludes checkpoints from the x-axis labels.
    """
    # Remove checkpoint info from model names for plotting
    df['model_plot_label'] = df['model_name']

    # Filter for the 'total' dataset
    total_data = df[df['dataset'] == 'total']

    # Select NIST-related metrics
    nist_metrics = ['macer', 'bpcer', 'macer_at_bpcer']

    # Group by model name and compute the mean for the total dataset
    metric_data = total_data.groupby("model_plot_label")[nist_metrics].mean()

    # Plot
    metric_data.plot(kind='bar', figsize=(10, 5), alpha=0.8, edgecolor='black')
    plt.title("NIST Metrics by Model for Total Dataset", fontsize=16)
    plt.ylabel("Metric Value", fontsize=14)
    plt.xlabel("Model", fontsize=14)
    plt.xticks(rotation=15, fontsize=12, ha="right")
    plt.legend(title="NIST Metrics", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
NIST_metrics()

# %%
def general_metrics():
    """
    Generates a bar chart of Accuracy, Precision, Recall, and F1-score for each model, 
    focusing only on the 'total' dataset.
    Excludes checkpoints from the x-axis labels and zooms y-axis to 0.8-1.0.
    """
    # Remove checkpoint info from model names for plotting
    df['model_plot_label'] = df['model_name']

    # Filter for the 'total' dataset
    total_data = df[df['dataset'] == 'total']

    # Select general performance metrics
    general_metrics = ['accuracy', 'precision', 'recall', 'f1_score']

    # Group by model name and compute the mean for the total dataset
    metric_data = total_data.groupby("model_plot_label")[general_metrics].mean()

    # Plot
    ax = metric_data.plot(kind='bar', figsize=(10, 5), alpha=0.8, edgecolor='black')
    plt.title("General Metrics by Model for Total Dataset", fontsize=16)
    plt.ylabel("Metric Value", fontsize=14)
    plt.xlabel("Model", fontsize=14)
    plt.xticks(rotation=15, fontsize=12, ha="right")
    plt.ylim(0.8, 1.0)  # Focus only on values between 0.8 and 1.0
    plt.legend(title="General Metrics", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
general_metrics()

# %%
def single_set(metrics=None, dataset_name=None):
    """
    Generates a bar chart of selected metrics by dataset for each model.
    Allows filtering by dataset (subfolder or 'total') and metric(s).

    Parameters:
    - metrics (str or list of str): Metric(s) to plot (default: 'macer_at_bpcer').
    - dataset_name (str): Specific dataset to filter (default: None, meaning all datasets are shown).
    """
    # Default to 'macer_at_bpcer' if no metric is provided
    if metrics is None:
        metrics = ['macer_at_bpcer']
    elif isinstance(metrics, str):
        metrics = [metrics]  # Convert single string to list for consistency

    # Remove checkpoint info from model names for plotting
    df['model_plot_label'] = df['model_name']

    # Filter by dataset if a specific one is given
    if dataset_name:
        filtered_df = df[df['dataset'] == dataset_name]
    else:
        filtered_df = df  # Use full data if no dataset is specified

    # Group by model and dataset, then extract selected metrics
    grouped = filtered_df.groupby(["model_plot_label", "dataset"])[metrics].mean()

    # Unstack for plotting
    metric_data = grouped.unstack()

    # Plot
    metric_data.plot(kind='bar', figsize=(14, 6), alpha=0.8, edgecolor='black')
    plt.title(f"{', '.join(metrics)} by Dataset for Each Model", fontsize=16)
    plt.ylabel("Metric Value", fontsize=14)
    plt.xlabel("Model", fontsize=14)
    plt.xticks(rotation=15, fontsize=12, ha='right')
    plt.legend(title="Dataset", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
single_set(dataset_name="total")

# %%
single_set(metrics=["accuracy", "precision"], dataset_name="total")
